# %%
import pandas as pd

# %%
from google.colab import files

# %%
uploded=files.upload()
# Out:
#      <input type="file" id="files-02db1f3e-1c6b-4fec-b23c-8878e437b91c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-02db1f3e-1c6b-4fec-b23c-8878e437b91c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io

# %%
df=pd.read_csv(io.BytesIO(uploded['sample-csv-files-sample4.csv']))

# %%
df.head()
# Out:
#    Game Number   "Game Length"
# 0            1              30
# 1            2              29
# 2            3              31
# 3            4              16
# 4            5              24

# %%
df.describe()
# Out:
#        Game Number   "Game Length"
# count  1000.000000     1000.000000
# mean    500.500000       35.411000
# std     288.819436       23.412608
# min       1.000000        7.000000
# 25%     250.750000       19.000000
# 50%     500.500000       30.000000
# 75%     750.250000       45.000000
# max    1000.000000      197.000000

# %%
df.size

df.isnull().sum()


df.select_dtypes(include=['number']).sum()


df.select_dtypes(include=['number']).mean()

df.select_dtypes(include=['number']).min()


df.select_dtypes(include=['number']).max()
# Out:
# Game Number       1000
#  "Game Length"     197
# dtype: int64

# %%
df.select_dtypes(include=['number']).max()
# Out:
# Game Number       1000
#  "Game Length"     197
# dtype: int64

# %%
df.select_dtypes(include=['number']).min()
# Out:
# Game Number       1
#  "Game Length"    7
# dtype: int64

# %%
df.select_dtypes(include=['number']).min()
# Out:
# Game Number       1
#  "Game Length"    7
# dtype: int64

# %%
df.select_dtypes(include=['number']).sum()
# Out:
# Game Number       500500
#  "Game Length"     35411
# dtype: int64

# %%
df.size
# Out:
# 2000

# %%
df.head()
# Out:
#    Game Number   "Game Length"
# 0            1              30
# 1            2              29
# 2            3              31
# 3            4              16
# 4            5              24
